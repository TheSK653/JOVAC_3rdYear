# %%
import pandas as pd

# %% [markdown]
# 1. Download a sample dataset from Kaggle or use any public dataset.

# %% [markdown]
# 2. Write a Python program to:
#
# A. Load the dataset using Pandas.

# %%
new_data = pd.read_csv('dataset.csv')
new_data.head()
# Out:
#    index                track_id                 artists  \
# 0      0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1      1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2      2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3      3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4      4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610  ...    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660  ...   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590  ...    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596  ...   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430  ...    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature  track_genre
# 0          0.000001    0.3580    0.715   87.917               4     acoustic
# 1          0.000006    0.1010    0.267   77.489               4     acoustic
# 2          0.000000    0.1170    0.120   76.332               4     acoustic
# 3          0.000071    0.1320    0.143  181.740               3     acoustic
# 4          0.000000    0.0829    0.167  119.949               4     acoustic
#
# [5 rows x 21 columns]

# %% [markdown]
# B. Perform exploratory data analysis (EDA) by summarizing key statistics, checking for missing values, and visualizing data trends using Matplotlib or
# Seaborn.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Key Statistics

new_data.describe()
# Out:
#               index    popularity   duration_ms  danceability        energy  \
# count  17506.000000  17506.000000  1.750600e+04  17506.000000  17506.000000
# mean    8752.500000     32.817320  2.387151e+05      0.555307      0.580992
# std     5053.691242     21.715945  1.417749e+05      0.181682      0.272894
# min        0.000000      0.000000  1.745300e+04      0.000000      0.000756
# 25%     4376.250000     16.000000  1.731330e+05      0.436000      0.371000
# 50%     8752.500000     33.000000  2.212795e+05      0.569000      0.607000
# 75%    13128.750000     50.000000  2.760000e+05      0.689000      0.824000
# max    17505.000000     93.000000  4.789026e+06      0.981000      1.000000
#
#                 key      loudness          mode   speechiness  acousticness  \
# count  17506.000000  17506.000000  17506.000000  17506.000000  17506.000000
# mean       5.310979     -9.555519      0.664744      0.069298      0.372466
# std        3.564343      5.758512      0.472094      0.072909      0.359478
# min        0.000000    -41.808000      0.000000      0.000000      0.000000
# 25%        2.000000    -11.529000      0.000000      0.034100      0.017000
# 50%        5.000000     -8.022000      1.000000      0.044400      0.260000
# 75%        9.000000     -5.752500      1.000000      0.069300      0.723000
# max       11.000000      0.698000      1.000000      0.943000      0.996000
#
#        instrumentalness      liveness       valence         tempo  \
# count      17506.000000  17506.000000  17506.000000  17506.000000
# mean           0.231493      0.192769      0.468395    121.276696
# std            0.357876      0.168426      0.267498     29.173168
# min            0.000000      0.011600      0.000000      0.000000
# 25%            0.000000      0.095300      0.242000     99.959000
# 50%            0.000688      0.123000      0.450000    121.744500
# 75%            0.490000      0.237000      0.686000    139.488750
# max            0.995000      0.995000      0.995000    243.372000
#
#        time_signature
# count    17506.000000
# mean         3.891409
# std          0.426792
# min          0.000000
# 25%          4.000000
# 50%          4.000000
# 75%          4.000000
# max          5.000000

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17506 entries, 0 to 17505
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             17506 non-null  int64
#  1   track_id          17506 non-null  object
#  2   artists           17506 non-null  object
#  3   album_name        17506 non-null  object
#  4   track_name        17506 non-null  object
#  5   popularity        17506 non-null  int64
#  6   duration_ms       17506 non-null  int64
#  7   explicit          17506 non-null  bool
#  8   danceability      17506 non-null  float64
#  9   energy            17506 non-null  float64
#  10  key               17506 non-null  int64
#  11  loudness          17506 non-null  float64
#  12  mode              17506 non-null  int64
#  13  speechiness       17506 non-null  float64
#  14  acousticness      17506 non-null  float64
#  15  instrumentalness  17506 non-null  float64
#  16  liveness          17506 non-null  float64
#  17  valence           17506 non-null  float64
#  18  tempo             17506 non-null  float64
#  19  time_signature    17506 non-null  int64
#  20  track_genre       17506 non-null  object
# dtypes: bool(1), float64(9), int64(6), object(5)
# memory usage: 2.7+ MB

# %%
#Missing Values

new_data.isnull().sum()
# Out:
# index               0
# track_id            0
# artists             0
# album_name          0
# track_name          0
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
#Histplot

plt.figure(figsize=(8,5))
sns.histplot(new_data['popularity'], bins=30, kde=True, color='blue')
plt.title('Distribution of Track Popularity')
plt.xlabel('Popularity')
plt.ylabel('Frequency')
plt.show()

# %%
#HeatMAP

plt.figure(figsize=(12,8))
sns.heatmap(new_data.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numeric Features')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# C. Document your findings in Markdown or comments.

# %% [markdown]
# ## Findings from Spotify Dataset EDA
#
# - The dataset contains popular track features such as danceability, energy, loudness, and popularity.
# - Most tracks have a popularity score between 50 and 80.
# - Danceability and energy show a positive correlation (~0.6), suggesting upbeat tracks are often more energetic.
# - There are few missing values, mostly in the 'genre' or metadata columns.
# - Average audio features vary significantly across genres — electronic and pop tracks tend to have higher energy and danceability.
